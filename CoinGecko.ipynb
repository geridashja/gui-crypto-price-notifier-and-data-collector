# %%
from pycoingecko import CoinGeckoAPI
import pandas as pd
cg = CoinGeckoAPI()

# %%
coins = cg.get_coins_list()

# %%
coins_df = pd.DataFrame(coins, columns=["name"])

# %%
coins_df.tail()
# Out:
#                 name
# 9436            Zyro
# 9437   Zytara Dollar
# 9438             ZYX
# 9439     zzz.finance
# 9440  zzz.finance v2

# %%
coins_market = cg.get_coins_markets(vs_currency='usd')

# %%
coins_market_df = pd.DataFrame(coins_market, columns=["id","current_price","market_cap"])

# %%
coins_market_df.head()
# Out:
#             id  current_price    market_cap
# 0      bitcoin       42270.00  793360291229
# 1     ethereum        2928.96  343375302501
# 2       tether           1.00   69323187269
# 3      cardano           2.12   67719742690
# 4  binancecoin         371.05   56952779588

# %%
kot = cg.get_coin_history_by_id(id="bitcoin",date='06-09-2021',localization='false')
# kot_df = pd.DataFrame(kot,columns=["current_price", "market_cap"])
# kot_df
kot
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579'},
#  'market_data': {'current_price': {'aed': 189882.28576669458,
#    'ars': 5058442.781580594,
#    'aud': 69418.85500872161,
#    'bch': 68.45962121981758,
#    'bdt': 4400764.212019643,
#    'bhd': 19484.765469821603,
#    'bmd': 51696.206431317885,
#    'bnb': 102.86074575372997,
#    'brl': 268370.516446901,
#    'btc': 1.0,
#    'cad': 64776.1221015378,
#    'chf': 47251.004728908134,
#    'clp': 39653575.143142395,
#    'cny': 333590.4504806509,
#    'czk': 1104282.6655793786,
#    'dkk': 323437.31553754007,
#    'dot': 1507.8358418136677,
#    'eos': 8251.814294200132,
#    'eth': 13.070863875782532,
#    'eur': 43495.171939260115,
#    'gbp': 37301.44944672385,
#    'hkd': 401739.4915708006,
#    'huf': 15124759.115610635,
# ...

# %%
coin_hist = cg.get_coin_history_by_id(id="bitcoin",date="06-12-2020",localization=False,vs_currency="usd")

# %%
import json
str_coin_hist = json.dumps(coin_hist)
data = json.loads(str_coin_hist)
df = pd.json_normalize(data['market_data'])

# %%
new_df = df.transpose()

# %%
new_df.insert(0, 'Coin_name', 'Bitcoin')

# %%
new_df
# Out:
#                   Coin_Name             0
# current_price.aed   Bitcoin  7.029796e+04
# current_price.ars   Bitcoin  1.562860e+06
# current_price.aud   Bitcoin  2.577694e+04
# current_price.bch   Bitcoin  6.698691e+01
# current_price.bdt   Bitcoin  1.622833e+06
# ...                     ...           ...
# total_volume.yfi    Bitcoin  7.942762e+05
# total_volume.zar    Bitcoin  3.549961e+11
# total_volume.bits   Bitcoin  1.219253e+12
# total_volume.link   Bitcoin  1.771011e+09
# total_volume.sats   Bitcoin  1.219253e+14
#
# [183 rows x 2 columns]

# %%
#has all the information, market cap, price for every currency and the volume on that day
new_df.to_csv('kot.csv')
